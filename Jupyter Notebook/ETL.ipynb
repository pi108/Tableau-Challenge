# %%
import pandas as pd
import random
import matplotlib.pyplot as plt
import numpy as np

# %%
df_202005 = pd.read_csv("Resources/JC-202005-citibike-tripdata.csv")

# %%
df_202005.shape
# Out:
# (25077, 21)

# %%
df_202005.head()
# Out:
#   datamonth  year  month  season  age  tripduration_mins   tripduration  \
# 0  5/1/2020  2020      5  Spring   51               5.82            349
# 1  5/1/2020  2020      5  Spring   71               2.30            138
# 2  5/1/2020  2020      5  Spring   36               3.82            229
# 3  5/1/2020  2020      5  Spring   46               4.35            261
# 4  5/1/2020  2020      5  Spring   54               2.80            168
#
#   starttime stoptime  start station id  ... start station latitude  \
# 0   09:45.6  15:35.3              3195  ...              40.730897
# 1   11:22.5  13:41.2              3792  ...              40.716870
# 2   31:29.5  35:19.2              3483  ...              40.719420
# 3   51:39.4  56:00.9              3278  ...              40.725685
# 4   06:32.0  09:20.1              3194  ...              40.725340
#
#    start station longitude  end station id  end station name  \
# 0               -74.063913            3280       Astor Place
# ...

# %%
df_202004 = pd.read_csv("Resources/JC-202004-citibike-tripdata.csv")

# %%
df_202004.shape
# Out:
# (9268, 21)

# %%
df_202004.head()
# Out:
#   datamonth  year  month  season  age  tripduration_mins   tripduration  \
# 0  4/1/2020  2020      4  Spring   18              23.95           1437
# 1  4/1/2020  2020      4  Spring   57               4.40            264
# 2  4/1/2020  2020      4  Spring   39               4.23            254
# 3  4/1/2020  2020      4  Spring   56               7.15            429
# 4  4/1/2020  2020      4  Spring   55              13.42            805
#
#   starttime stoptime  start station id  ... start station latitude  \
# 0   06:20.6  30:18.0              3678  ...              40.725726
# 1   02:42.1  07:06.1              3207  ...              40.737604
# 2   20:28.1  24:42.1              3678  ...              40.725726
# 3   33:30.5  40:40.2              3195  ...              40.730897
# 4   38:32.9  51:58.2              3193  ...              40.724605
#
#    start station longitude  end station id  end station name  \
# 0               -74.071959            3678     Fairmount Ave
# ...

# %%
df_202003 = pd.read_csv("Resources/JC-202003-citibike-tripdata.csv")

# %%
df_202003.shape
# Out:
# (17719, 21)

# %%
df_202003.head()
# Out:
#   datamonth  year  month  season  age  tripduration_mins   tripduration  \
# 0  3/1/2020  2020      3  Spring   28               6.48            389
# 1  3/1/2020  2020      3  Spring   29               4.03            242
# 2  3/1/2020  2020      3  Spring   33               2.07            124
# 3  3/1/2020  2020      3  Spring   27               1.73            104
# 4  3/1/2020  2020      3  Spring   32               3.80            228
#
#   starttime stoptime  start station id  ... start station latitude  \
# 0   14:07.0  20:36.1              3202  ...              40.727224
# 1   48:06.4  52:09.0              3185  ...              40.717733
# 2   08:46.5  10:51.3              3272  ...              40.723332
# 3   22:35.5  24:20.2              3202  ...              40.727224
# 4   39:20.3  43:09.1              3194  ...              40.725340
#
#    start station longitude  end station id   end station name  \
# 0               -74.033759            3203      Hamilton Park
# ...

# %%
df_202002 = pd.read_csv("Resources/JC-202002-citibike-tripdata.csv")

# %%
df_202002.shape
# Out:
# (22962, 21)

# %%
df_202002.head()
# Out:
#   datamonth  year  month  season  age  tripduration_mins   tripduration  \
# 0  2/1/2020  2020      2  Winter   40              14.02            841
# 1  2/1/2020  2020      2  Winter   30               3.43            206
# 2  2/1/2020  2020      2  Winter   29              14.32            859
# 3  2/1/2020  2020      2  Winter   33              11.55            693
# 4  2/1/2020  2020      2  Winter   51              24.55           1473
#
#   starttime stoptime  start station id  ... start station latitude  \
# 0   02:13.8  16:15.5              3199  ...              40.728745
# 1   16:11.4  19:37.4              3273  ...              40.721651
# 2   23:22.1  37:41.5              3185  ...              40.717733
# 3   25:14.5  36:48.0              3185  ...              40.717733
# 4   32:30.5  57:04.4              3192  ...              40.711242
#
#    start station longitude  end station id         end station name  \
# ...

# %%
df_202001 = pd.read_csv("Resources/JC-202001-citibike-tripdata.csv")

# %%
df_202001.shape
# Out:
# (26020, 21)

# %%
df_202001.head()
# Out:
#   datamonth  year  month  season  age  tripduration_mins   tripduration  \
# 0  1/1/2020  2020      1  Winter   36               3.77            226
# 1  1/1/2020  2020      1  Winter   31               6.28            377
# 2  1/1/2020  2020      1  Winter   31               4.80            288
# 3  1/1/2020  2020      1  Winter   51               7.25            435
# 4  1/1/2020  2020      1  Winter   37               3.85            231
#
#   starttime stoptime  start station id  ... start station latitude  \
# 0   04:50.2  08:37.0              3186  ...              40.719586
# 1   16:01.7  22:19.1              3186  ...              40.719586
# 2   17:33.9  22:22.4              3186  ...              40.719586
# 3   32:05.9  39:21.1              3195  ...              40.730897
# 4   46:19.7  50:11.3              3186  ...              40.719586
#
#    start station longitude  end station id  end station name  \
# 0               -74.043117            3211        Newark Ave
# ...

# %%
df_201912 = pd.read_csv("Resources/JC-201912-citibike-tripdata.csv")

# %%
df_201912.shape
# Out:
# (19728, 21)

# %%
df_201912.head()
# Out:
#    datamonth  year  month  season  age  tripduration_mins   tripduration  \
# 0  12/1/2019  2019     12  Winter   39              25.88           1553
# 1  12/1/2019  2019     12  Winter   63               6.93            416
# 2  12/1/2019  2019     12  Winter   42               4.90            294
# 3  12/1/2019  2019     12  Winter   26               1.62             97
# 4  12/1/2019  2019     12  Winter   29               4.77            286
#
#   starttime stoptime  start station id  ... start station latitude  \
# 0   07:13.9  33:07.7              3681  ...              40.715178
# 1   16:40.5  23:36.6              3195  ...              40.730897
# 2   20:29.8  25:24.0              3195  ...              40.730897
# 3   21:13.8  22:51.6              3202  ...              40.727224
# 4   29:58.0  34:44.2              3195  ...              40.730897
#
#    start station longitude  end station id  end station name  \
# ...

# %%
df_201911 = pd.read_csv("Resources/JC-201911-citibike-tripdata.csv")

# %%
df_201911.shape
# Out:
# (30797, 21)

# %%
df_201911.head()
# Out:
#    datamonth  year  month season  age  tripduration_mins   tripduration  \
# 0  11/1/2019  2019     11   Fall   55               4.33            260
# 1  11/1/2019  2019     11   Fall   33               4.75            285
# 2  11/1/2019  2019     11   Fall   24               8.35            501
# 3  11/1/2019  2019     11   Fall   27               9.27            556
# 4  11/1/2019  2019     11   Fall   31               5.35            321
#
#   starttime stoptime  start station id  ... start station latitude  \
# 0   02:53.9  07:14.6              3186  ...              40.719586
# 1   05:38.6  10:24.2              3206  ...              40.731169
# 2   05:43.6  14:05.5              3186  ...              40.719586
# 3   07:57.1  17:13.9              3209  ...              40.724176
# 4   11:44.6  17:05.6              3273  ...              40.721651
#
#    start station longitude  end station id    end station name  \
# ...

# %%
df_201910 = pd.read_csv("Resources/JC-201910-citibike-tripdata.csv")

# %%
df_201910.shape
# Out:
# (42253, 21)

# %%
df_201910.head()
# Out:
#    datamonth  year  month season  age  tripduration_mins   tripduration  \
# 0  10/1/2019  2019     10   Fall   43              14.87            892
# 1  10/1/2019  2019     10   Fall   35               6.23            374
# 2  10/1/2019  2019     10   Fall   33               2.83            170
# 3  10/1/2019  2019     10   Fall   50              15.77            946
# 4  10/1/2019  2019     10   Fall   50               8.62            517
#
#   starttime stoptime  start station id  ... start station latitude  \
# 0   20:05.0  34:57.4              3275  ...              40.718355
# 1   43:48.9  50:03.8              3211  ...              40.721525
# 2   35:51.9  38:42.5              3194  ...              40.725340
# 3   55:53.4  11:40.3              3272  ...              40.723332
# 4   10:16.1  18:53.6              3206  ...              40.731169
#
#    start station longitude  end station id            end station name  \
# ...

# %%
df_201909 = pd.read_csv("Resources/JC-201909-citibike-tripdata.csv")

# %%
df_201909.shape
# Out:
# (49244, 21)

# %%
df_201909.head()
# Out:
#   datamonth  year  month season  age  tripduration_mins   tripduration  \
# 0  9/1/2019  2019      9   Fall   28               2.42            145
# 1  9/1/2019  2019      9   Fall   26               3.53            212
# 2  9/1/2019  2019      9   Fall   42               9.48            569
# 3  9/1/2019  2019      9   Fall   54              23.00           1380
# 4  9/1/2019  2019      9   Fall   51              22.43           1346
#
#   starttime stoptime  start station id  ... start station latitude  \
# 0   00:37.7  03:03.0              3640  ...              40.733670
# 1   03:00.6  06:33.3              3194  ...              40.725340
# 2   07:13.0  16:42.9              3214  ...              40.712774
# 3   07:25.3  30:26.2              3214  ...              40.712774
# 4   07:56.5  30:22.5              3214  ...              40.712774
#
#    start station longitude  end station id            end station name  \
# ...

# %%
df_201908 = pd.read_csv("Resources/JC-201908-citibike-tripdata.csv")

# %%
df_201908.shape
# Out:
# (48711, 21)

# %%
df_201908.head()
# Out:
#   datamonth  year  month  season  age  tripduration_mins   tripduration  \
# 0  8/1/2019  2019      8  Summer   39               4.35            261
# 1  8/1/2019  2019      8  Summer   23               2.87            172
# 2  8/1/2019  2019      8  Summer   28               8.75            525
# 3  8/1/2019  2019      8  Summer   31               3.65            219
# 4  8/1/2019  2019      8  Summer   59               4.37            262
#
#   starttime stoptime  start station id  ... start station latitude  \
# 0   14:56.0  19:17.5              3205  ...              40.716540
# 1   23:07.0  25:59.1              3279  ...              40.721630
# 2   23:28.6  32:13.7              3199  ...              40.728745
# 3   32:36.1  36:15.3              3187  ...              40.721124
# 4   41:26.7  45:49.4              3186  ...              40.719586
#
#    start station longitude  end station id    end station name  \
# ...

# %%
df_201907 = pd.read_csv("Resources/JC-201907-citibike-tripdata.csv")

# %%
df_201907.shape
# Out:
# (43746, 21)

# %%
df_201907.head()
# Out:
#   datamonth  year  month  season  age  tripduration_mins   tripduration  \
# 0  7/1/2019  2019      7  Summer   41              29.88           1793
# 1  7/1/2019  2019      7  Summer   31               7.23            434
# 2  7/1/2019  2019      7  Summer   33               4.18            251
# 3  7/1/2019  2019      7  Summer   23              10.60            636
# 4  7/1/2019  2019      7  Summer   30              10.38            623
#
#   starttime stoptime  start station id  ... start station latitude  \
# 0   00:36.6  30:30.6              3186  ...              40.719586
# 1   02:54.6  10:09.0              3206  ...              40.731169
# 2   03:27.6  07:38.6              3186  ...              40.719586
# 3   03:56.2  14:32.4              3206  ...              40.731169
# 4   04:16.2  14:40.0              3206  ...              40.731169
#
#    start station longitude  end station id     end station name  \
# ...

# %%
df_201906 = pd.read_csv("Resources/JC-201906-citibike-tripdata.csv")

# %%
df_201906.shape
# Out:
# (39430, 21)

# %%
df_201906.head()
# Out:
#   datamonth  year  month  season  age  tripduration_mins   tripduration  \
# 0  6/1/2019  2019      6  Summer   26               5.27            316
# 1  6/1/2019  2019      6  Summer   35               4.67            280
# 2  6/1/2019  2019      6  Summer   50              36.03           2162
# 3  6/1/2019  2019      6  Summer   50              36.40           2184
# 4  6/1/2019  2019      6  Summer   25               2.32            139
#
#   starttime stoptime  start station id  ... start station latitude  \
# 0   05:55.7  11:12.0              3187  ...              40.721124
# 1   08:09.1  12:50.1              3185  ...              40.717733
# 2   13:11.9  49:14.4              3199  ...              40.728745
# 3   13:30.1  49:54.2              3199  ...              40.728745
# 4   13:31.9  15:51.8              3207  ...              40.737604
#
#    start station longitude  end station id  end station name  \
# 0               -74.038051            3199      Newport Pkwy
# ...

# %%
df_201905 = pd.read_csv("Resources/JC-201905-citibike-tripdata.csv")

# %%
df_201905.shape
# Out:
# (36135, 21)

# %%
df_201905.head()
# Out:
#   datamonth  year  month  season  age  tripduration_mins   tripduration  \
# 0  5/1/2019  2019      5  Spring   31                5.18           311
# 1  5/1/2019  2019      5  Spring   45                8.97           538
# 2  5/1/2019  2019      5  Spring   31                2.97           178
# 3  5/1/2019  2019      5  Spring   33                5.28           317
# 4  5/1/2019  2019      5  Spring   33                 5.9           354
#
#   starttime stoptime  start station id  ... start station latitude  \
# 0   07:36.5  12:47.6              3185  ...              40.717733
# 1   08:29.3  17:27.9              3681  ...              40.715178
# 2   39:36.5  42:35.0              3638  ...              40.724294
# 3   24:28.0  29:45.6              3206  ...              40.731169
# 4   54:39.7  00:34.2              3639  ...              40.719252
#
#    start station longitude  end station id  end station name  \
# 0               -74.043845            3279       Dixon Mills
# ...

# %%
df_201904 = pd.read_csv("Resources/JC-201904-citibike-tripdata.csv")
# Out:
# C:\Users\firdo\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3058: DtypeWarning: Columns (5) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
df_201904.shape
# Out:
# (33056, 21)

# %%
df_201904.head()
# Out:
#   datamonth  year  month  season  age  tripduration_mins   tripduration  \
# 0  4/1/2019  2019      4  Spring   53               1.78            107
# 1  4/1/2019  2019      4  Spring   29               8.22            493
# 2  4/1/2019  2019      4  Spring   32               8.53            512
# 3  4/1/2019  2019      4  Spring   30               3.27            196
# 4  4/1/2019  2019      4  Spring   24               7.72            463
#
#   starttime stoptime  start station id  ... start station latitude  \
# 0   48:04.8  49:52.4              3183  ...              40.716247
# 1   41:09.7  49:23.0              3183  ...              40.716247
# 2   27:07.9  35:40.9              3183  ...              40.716247
# 3   07:38.2  10:54.6              3183  ...              40.716247
# 4   19:24.7  27:08.6              3183  ...              40.716247
#
#    start station longitude  end station id  end station name  \
# 0               -74.033459            3184       Paulus Hook
# ...

# %%
df_201903 = pd.read_csv("Resources/JC-201903-citibike-tripdata.csv")

# %%
df_201903.shape
# Out:
# (23606, 21)

# %%
df_201903.head()
# Out:
#   datamonth  year  month  season  age  tripduration_mins   tripduration  \
# 0  3/1/2019  2019      3  Spring   30               5.10            306
# 1  3/1/2019  2019      3  Spring   53               2.05            123
# 2  3/1/2019  2019      3  Spring   48               5.47            328
# 3  3/1/2019  2019      3  Spring   34               1.58             95
# 4  3/1/2019  2019      3  Spring   48               2.82            169
#
#   starttime stoptime  start station id  ... start station latitude  \
# 0   47:08.2  52:14.7              3183  ...              40.716247
# 1   30:53.0  32:56.8              3183  ...              40.716247
# 2   18:30.4  23:59.1              3183  ...              40.716247
# 3   04:47.2  06:22.8              3183  ...              40.716247
# 4   51:29.4  54:19.2              3183  ...              40.716247
#
#    start station longitude  end station id  end station name  \
# 0               -74.033459            3267      Morris Canal
# ...

# %%
df_201902 = pd.read_csv("Resources/JC-201902-citibike-tripdata.csv")

# %%
df_201902.shape
# Out:
# (18565, 21)

# %%
df_201902.head()
# Out:
#   datamonth  year  month  season  age  tripduration_mins   tripduration  \
# 0  2/1/2019  2019      2  Winter   56               2.37            142
# 1  2/1/2019  2019      2  Winter   27               3.72            223
# 2  2/1/2019  2019      2  Winter   59               1.77            106
# 3  2/1/2019  2019      2  Winter   43               6.17            370
# 4  2/1/2019  2019      2  Winter   39               5.25            315
#
#   starttime stoptime  start station id  ... start station latitude  \
# 0   35:02.1  37:24.1              3183  ...              40.716247
# 1   00:46.9  04:30.5              3183  ...              40.716247
# 2   08:01.3  09:47.4              3183  ...              40.716247
# 3   09:31.2  15:41.7              3183  ...              40.716247
# 4   19:53.2  25:09.1              3183  ...              40.716247
#
#    start station longitude  end station id  end station name  \
# 0               -74.033459            3639        Harborside
# ...

# %%
df_201901 = pd.read_csv("Resources/JC-201901-citibike-tripdata.csv")

# %%
df_201901.shape
# Out:
# (19676, 21)

# %%
df_201901.head()
# Out:
#   datamonth  year  month  season  age  tripduration_mins   tripduration  \
# 0  1/1/2019  2019      1  Winter   26               3.35            201
# 1  1/1/2019  2019      1  Winter   47               8.42            505
# 2  1/1/2019  2019      1  Winter   34              12.60            756
# 3  1/1/2019  2019      1  Winter   50              26.25           1575
# 4  1/1/2019  2019      1  Winter   50              26.10           1566
#
#   starttime stoptime  start station id  ... start station latitude  \
# 0   09:09.7  12:30.9              3183  ...              40.716247
# 1   18:00.1  26:25.9              3183  ...              40.716247
# 2   36:33.3  49:10.3              3183  ...              40.716247
# 3   43:38.6  09:54.5              3183  ...              40.716247
# 4   43:39.6  09:46.5              3183  ...              40.716247
#
#    start station longitude  end station id    end station name  \
# ...

# %%
df_201812 = pd.read_csv("Resources/JC-201812-citibike-tripdata.csv")

# %%
df_201812.shape
# Out:
# (20205, 21)

# %%
df_201812.head()
# Out:
#    datamonth  year  month  season  age  tripduration_mins   tripduration  \
# 0  12/1/2018  2018     12  Winter   43               2.83            170
# 1  12/1/2018  2018     12  Winter   30               2.87            172
# 2  12/1/2018  2018     12  Winter   28               4.12            247
# 3  12/1/2018  2018     12  Winter   23               6.77            406
# 4  12/1/2018  2018     12  Winter   42               5.90            354
#
#   starttime stoptime  start station id  ... start station latitude  \
# 0   03:53.4  06:43.7              3183  ...              40.716247
# 1   47:13.7  50:05.8              3183  ...              40.716247
# 2   48:57.7  53:05.7              3183  ...              40.716247
# 3   33:53.7  40:39.7              3183  ...              40.716247
# 4   26:52.5  32:46.5              3183  ...              40.716247
#
#    start station longitude  end station id  end station name  \
# ...

# %%
df_201811 = pd.read_csv("Resources/JC-201811-citibike-tripdata.csv")

# %%
df_201811.shape
# Out:
# (24910, 21)

# %%
df_201811.head()
# Out:
#    datamonth  year  month season  age  tripduration_mins   tripduration  \
# 0  11/1/2018  2018     11   Fall   49              19.80           1188
# 1  11/1/2018  2018     11   Fall   55               4.63            278
# 2  11/1/2018  2018     11   Fall   52               1.92            115
# 3  11/1/2018  2018     11   Fall   43               2.58            155
# 4  11/1/2018  2018     11   Fall   43               1.37             82
#
#   starttime stoptime  start station id  ... start station latitude  \
# 0   32:27.5  52:15.9              3183  ...              40.716247
# 1   14:31.9  19:10.3              3183  ...              40.716247
# 2   33:17.2  35:12.3              3183  ...              40.716247
# 3   20:10.9  22:46.7              3183  ...              40.716247
# 4   35:02.8  36:25.2              3183  ...              40.716247
#
#    start station longitude  end station id  end station name  \
# 0               -74.033459            3199      Newport Pkwy
# ...

# %%
df_201810 = pd.read_csv("Resources/JC-201810-citibike-tripdata.csv")

# %%
df_201810.shape
# Out:
# (39138, 21)

# %%
df_201810.head()
# Out:
#    datamonth  year  month season  age  tripduration_mins   tripduration  \
# 0  10/1/2018  2018     10   Fall   47               2.53            152
# 1  10/1/2018  2018     10   Fall   45               2.03            122
# 2  10/1/2018  2018     10   Fall   60               3.52            211
# 3  10/1/2018  2018     10   Fall   36               5.70            342
# 4  10/1/2018  2018     10   Fall   49              49.60           2976
#
#   starttime stoptime  start station id  ... start station latitude  \
# 0   44:41.4  47:14.3              3183  ...              40.716247
# 1   50:05.4  52:08.2              3183  ...              40.716247
# 2   03:17.1  06:48.1              3183  ...              40.716247
# 3   13:07.0  18:49.9              3183  ...              40.716247
# 4   45:14.3  34:51.3              3183  ...              40.716247
#
#    start station longitude  end station id  end station name  \
# 0               -74.033459            3639        Harborside
# ...

# %%
df_201809 = pd.read_csv("Resources/JC-201809-citibike-tripdata.csv")

# %%
df_201809.shape
# Out:
# (39022, 21)

# %%
df_201809.head()
# Out:
#   datamonth  year  month season  age  tripduration_mins   tripduration  \
# 0  9/1/2018  2018      9   Fall   34               4.73            284
# 1  9/1/2018  2018      9   Fall   34               6.17            370
# 2  9/1/2018  2018      9   Fall   24              19.68           1181
# 3  9/1/2018  2018      9   Fall   31               6.38            383
# 4  9/1/2018  2018      9   Fall   33               6.28            377
#
#   starttime stoptime  start station id  ... start station latitude  \
# 0   48:22.0  53:06.9              3183  ...              40.716247
# 1   48:22.5  54:32.9              3183  ...              40.716247
# 2   37:04.3  56:45.3              3183  ...              40.716247
# 3   44:46.0  51:09.9              3183  ...              40.716247
# 4   44:46.2  51:03.6              3183  ...              40.716247
#
#    start station longitude  end station id    end station name  \
# 0               -74.033459            3267        Morris Canal
# ...

# %%
df_201808 = pd.read_csv("Resources/JC-201808-citibike-tripdata.csv")

# %%
df_201808.shape
# Out:
# (44432, 21)

# %%
df_201808.head()
# Out:
#   datamonth  year  month  season  age  tripduration_mins   tripduration  \
# 0  8/1/2018  2018      8  Summer   41              15.05            903
# 1  8/1/2018  2018      8  Summer   43               1.30             78
# 2  8/1/2018  2018      8  Summer   45               6.75            405
# 3  8/1/2018  2018      8  Summer   47               2.58            155
# 4  8/1/2018  2018      8  Summer   25               7.55            453
#
#   starttime stoptime  start station id  ... start station latitude  \
# 0   40:33.4  55:37.1              3183  ...              40.716247
# 1   21:00.1  22:18.6              3183  ...              40.716247
# 2   43:52.5  50:37.6              3183  ...              40.716247
# 3   48:24.9  51:00.9              3183  ...              40.716247
# 4   15:35.1  23:08.9              3183  ...              40.716247
#
#    start station longitude  end station id  end station name  \
# 0               -74.033459            3270   Jersey & 6th St
# ...

# %%
df_201807 = pd.read_csv("Resources/JC-201807-citibike-tripdata.csv")

# %%
df_201807.shape
# Out:
# (42268, 21)

# %%
df_201807.head()
# Out:
#   datamonth  year  month  season  age  tripduration_mins   tripduration  \
# 0  7/1/2018  2018      7  Summer   49              20.57           1234
# 1  7/1/2018  2018      7  Summer   49              17.35           1041
# 2  7/1/2018  2018      7  Summer   49              38.47           2308
# 3  7/1/2018  2018      7  Summer   26              12.78            767
# 4  7/1/2018  2018      7  Summer   46               2.52            151
#
#   starttime stoptime  start station id  ... start station latitude  \
# 0   08:39.9  29:14.5              3183  ...              40.716247
# 1   09:07.5  26:28.9              3183  ...              40.716247
# 2   14:45.7  53:14.6              3183  ...              40.716247
# 3   25:12.4  38:00.1              3183  ...              40.716247
# 4   07:44.1  10:15.8              3183  ...              40.716247
#
#    start station longitude  end station id  end station name  \
# 0               -74.033459            3183    Exchange Place
# ...

# %%
df_201806 = pd.read_csv("Resources/JC-201806-citibike-tripdata.csv")

# %%
df_201806.shape
# Out:
# (40937, 21)

# %%
df_201806.head()
# Out:
#   datamonth  year  month  season  age  tripduration_mins   tripduration  \
# 0  6/1/2018  2018      6  Summer   27               5.48            329
# 1  6/1/2018  2018      6  Summer   29               4.32            259
# 2  6/1/2018  2018      6  Summer   28              11.43            686
# 3  6/1/2018  2018      6  Summer   25               2.73            164
# 4  6/1/2018  2018      6  Summer   41              12.82            769
#
#   starttime stoptime  start station id  ... start station latitude  \
# 0   07:00.3  12:30.2              3183  ...              40.716247
# 1   24:43.8  29:03.8              3183  ...              40.716247
# 2   17:49.6  29:16.2              3183  ...              40.716247
# 3   44:00.4  46:44.7              3183  ...              40.716247
# 4   59:28.8  12:18.7              3183  ...              40.716247
#
#    start station longitude  end station id  end station name  \
# 0               -74.033459            3276  Marin Light Rail
# ...

# %%
df_201805 = pd.read_csv("Resources/JC-201805-citibike-tripdata.csv")

# %%
df_201805.shape
# Out:
# (34456, 21)

# %%
df_201805.head()
# Out:
#   datamonth  year  month  season  age  tripduration_mins   tripduration  \
# 0  5/1/2018  2018      5  Spring   52               2.18            131
# 1  5/1/2018  2018      5  Spring   43               1.22             73
# 2  5/1/2018  2018      5  Spring   49              82.15           4929
# 3  5/1/2018  2018      5  Spring   45               7.20            432
# 4  5/1/2018  2018      5  Spring   59               7.20            432
#
#   starttime stoptime  start station id  ... start station latitude  \
# 0   29:57.5  32:08.6              3183  ...              40.716247
# 1   13:58.3  15:11.9              3183  ...              40.716247
# 2   17:21.3  39:31.1              3183  ...              40.716247
# 3   25:58.7  33:10.9              3183  ...              40.716247
# 4   28:09.9  35:22.1              3183  ...              40.716247
#
#    start station longitude  end station id  end station name  \
# 0               -74.033459            3184       Paulus Hook
# ...

# %%
df_201804 = pd.read_csv("Resources/JC-201804-citibike-tripdata.csv")

# %%
df_201804.shape
# Out:
# (23634, 21)

# %%
df_201804.head()
# Out:
#   datamonth  year  month  season  age  tripduration_mins   tripduration  \
# 0  4/1/2018  2018      4  Spring   40              30.00           1814
# 1  4/1/2018  2018      4  Spring   39               5.00            298
# 2  4/1/2018  2018      4  Spring   46              18.00           1060
# 3  4/1/2018  2018      4  Spring   35              17.00           1035
# 4  4/1/2018  2018      4  Spring   29               9.00            559
#
#   starttime stoptime  start station id  ... start station latitude  \
# 0   43:51.2  14:06.1              3183  ...              40.716247
# 1   42:53.7  47:51.9              3183  ...              40.716247
# 2   43:12.0  00:52.9              3183  ...              40.716247
# 3   43:40.6  00:55.7              3183  ...              40.716247
# 4   56:47.5  06:06.8              3183  ...              40.716247
#
#    start station longitude  end station id    end station name  \
# ...

# %%
df_201803 = pd.read_csv("Resources/JC-201803-citibike-tripdata.csv")

# %%
df_201803.shape
# Out:
# (17109, 21)

# %%
df_201803.head()
# Out:
#   datamonth  year  month  season  age  tripduration_mins   tripduration  \
# 0  3/1/2018  2018      3  Spring   37               5.00            329
# 1  3/1/2018  2018      3  Spring   52               2.00            118
# 2  3/1/2018  2018      3  Spring   43               1.00             76
# 3  3/1/2018  2018      3  Spring   48              10.00            578
# 4  3/1/2018  2018      3  Spring   39               8.00            485
#
#   starttime stoptime  start station id  ... start station latitude  \
# 0   37:37.0  43:06.6              3183  ...              40.716247
# 1   37:30.1  39:28.4              3183  ...              40.716247
# 2   26:17.9  27:34.7              3183  ...              40.716247
# 3   10:36.2  20:14.9              3183  ...              40.716247
# 4   21:47.9  29:53.3              3183  ...              40.716247
#
#    start station longitude  end station id  end station name  \
# 0               -74.033459            3202      Newport PATH
# ...

# %%
df_201802 = pd.read_csv("Resources/JC-201802-citibike-tripdata.csv")

# %%
df_201802.shape
# Out:
# (15104, 21)

# %%
df_201802.head()
# Out:
#   datamonth  year  month  season  age  tripduration_mins   tripduration  \
# 0  2/1/2018  2018      2  Winter   52               2.00            134
# 1  2/1/2018  2018      2  Winter   32               7.00            413
# 2  2/1/2018  2018      2  Winter   43               1.00             77
# 3  2/1/2018  2018      2  Winter   38               7.00            404
# 4  2/1/2018  2018      2  Winter   32               4.00            230
#
#   starttime stoptime  start station id  ... start station latitude  \
# 0   38:15.9  40:30.6              3183  ...              40.716247
# 1   19:35.8  26:29.6              3183  ...              40.716247
# 2   31:03.1  32:20.4              3183  ...              40.716247
# 3   23:15.1  29:59.9              3183  ...              40.716247
# 4   26:01.8  29:52.5              3183  ...              40.716247
#
#    start station longitude  end station id  end station name  \
# 0               -74.033459            3184       Paulus Hook
# ...

# %%
df_201801 = pd.read_csv("Resources/JC-201801-citibike-tripdata.csv")

# %%
df_201801.shape
# Out:
# (12677, 21)

# %%
df_201801.head()
# Out:
#   datamonth  year  month  season  age  tripduration_mins   tripduration  \
# 0  1/1/2018  2018      1  Winter   26              15.53            932
# 1  1/1/2018  2018      1  Winter   49               9.17            550
# 2  1/1/2018  2018      1  Winter   72               8.50            510
# 3  1/1/2018  2018      1  Winter   24               5.90            354
# 4  1/1/2018  2018      1  Winter   27               4.17            250
#
#   starttime stoptime  start station id  ... start station latitude  \
# 0   06:17.5  21:50.0              3183  ...              40.716247
# 1   06:18.0  15:28.4              3183  ...              40.716247
# 2   06:57.0  15:27.8              3183  ...              40.716247
# 3   53:10.2  59:05.1              3183  ...              40.716247
# 4   34:30.2  38:41.0              3183  ...              40.716247
#
#    start station longitude  end station id  end station name  \
# 0               -74.033459            3199      Newport Pkwy
# ...

# %%
df_list = [df_202005, df_202004,  df_202003,  df_202002, df_202001, df_201912, df_201911, df_201910, df_201909, df_201908, df_201907, df_201906, df_201905, df_201904, df_201903, df_201902, df_201901, df_201812, df_201811, df_201810, df_201809, df_201808, df_201807, df_201806, df_201805, df_201804, df_201803, df_201802, df_201801]

# %%
df_combined = pd.concat(df_list)

# %%
df_combined.shape
# Out:
# (859885, 21)

# %%
df_combined['gender'].replace([0,1,2],['Unknown','Male','Female'],inplace=True)

# %%
df_combined.shape
# Out:
# (859885, 21)

# %%
df_combined_2 = df_combined[df_combined.gender != 'Unknown']

# %%
df_combined_2.shape
# Out:
# (801514, 21)

# %%
df_combined_2 = df_combined_2[df_combined_2.age < 61]

# %%
df_combined_2.shape
# Out:
# (775202, 21)

# %%
df_combined.to_excel("Output/Combined_Data_ALL.xlsx", index=False)

# %%
df_combined_2.to_excel("Output/Combined_Data_Transformed.xlsx", index=False)
